# %%
# Investment case study python file
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# # Task 1 : Load companies data into companies data frame

# %%
companies = pd.read_csv("companies.txt", sep="\t",encoding = "ISO-8859-1")
companies['permalink']=companies['permalink'].str.lower()
companies['permalink']=companies['permalink'].str.strip()
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# ...

# %% [markdown]
# # Task 2: Load rounds data into rounds2 data frame

# %%
rounds2 = pd.read_csv("rounds2.csv",encoding = "ISO-8859-1")
rounds2['company_permalink']=rounds2['company_permalink'].str.lower()
rounds2['company_permalink']=rounds2['company_permalink'].str.strip()
rounds2.info()
rounds2.describe()
rounds2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 6 columns):
# company_permalink          114949 non-null object
# funding_round_permalink    114949 non-null object
# funding_round_type         114949 non-null object
# funding_round_code         31140 non-null object
# funded_at                  114949 non-null object
# raised_amount_usd          94959 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 5.3+ MB
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /organization/-qounter
# 2               /organization/-qounter
# 3  /organization/-the-one-of-them-inc-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# ...

# %% [markdown]
# # Task 4: Compute no. of unique companies in round2
# ### Outcome: Item #1 in Table 1.1 of excel sheet

# %%
rounds2.company_permalink.unique().size
# Out:
# 66370

# %% [markdown]
# # Task 5: Compute no. of unique companies in companies
# ### Outcome: Item #2 in Table 1.1 of excel sheet

# %%
companies.permalink.unique().size
# Out:
# 66368

# %% [markdown]
# # Task 6: Identify column in companies df that can be used as unique key for each company
# ### Outcome: Item #3 in Table 1.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 7: Check if there are companies in round2 that are not in companies
# ### Outcome: Item #4 in Table 1.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 8: Resolve encoding issue in permalink column
# ### Outcome: Updated master_frame data frame

# %%
#Removing the encoded values from the comany permalink column
companies.permalink=companies.permalink.str.encode('utf-8').str.decode('ascii', 'ignore')
rounds2.company_permalink=rounds2.company_permalink.str.encode('utf-8').str.decode('ascii', 'ignore')
companies.head()
print("Rounds2 data:",rounds2.company_permalink.unique().size)
print("companies data:",companies.permalink.unique().size)
# Out:
# Rounds2 data: 66368
# companies data: 66368

# %%
rounds2.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /organization/-qounter
# 2               /organization/-qounter
# 3  /organization/-the-one-of-them-inc-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %% [markdown]
# # Task 9: Merge companies & round2 data frames into master_frame df and compute total no. of observations in master_frame
# ### Outcome: Item#5 in Table 1.1 of excel sheet; master_frame data frame"

# %%
companies.rename(columns={'permalink': 'company_permalink'},inplace=True)
master_frame=pd.merge(rounds2, companies, how='left', on='company_permalink')
master_frame.raised_amount_usd.sort_values(ascending = False)
#master_frame.loc[pd.isnull(master_frame['raised_amount_usd']), ['raised_amount_usd']]=7000000
master_frame = master_frame[~master_frame.raised_amount_usd.isnull()]
master_frame['raised_amount_usd']=master_frame['raised_amount_usd']/1000000
master_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94959 entries, 0 to 114948
# Data columns (total 15 columns):
# company_permalink          94959 non-null object
# funding_round_permalink    94959 non-null object
# funding_round_type         94959 non-null object
# funding_round_code         28169 non-null object
# funded_at                  94959 non-null object
# raised_amount_usd          94959 non-null float64
# name                       94958 non-null object
# homepage_url               90627 non-null object
# category_list              93915 non-null object
# status                     94959 non-null object
# country_code               89108 non-null object
# state_code                 87355 non-null object
# region                     87911 non-null object
# city                       87914 non-null object
# founded_at                 78993 non-null object
# dtypes: float64(1), object(14)
# memory usage: 11.6+ MB

# %%
master_frame
inv_by_funding_type=master_frame.groupby('funding_round_type')

# %% [markdown]
# # Task 10: Resolve encoding issue in company_permalink
# ### Outcome: Updated master_frame data frame

# %%
master_frame
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 15                                        /organization/1
# 16                              /organization/1-2-3-listo
# 20                            /organization/1-800-doctors
# ...

# %% [markdown]
# # Task 11: Compute average funding amount of venture type
# ### Outcome: Item #1 in Table 2.1 of excel sheet

# %%
inv_by_funding_type['raised_amount_usd'].mean().sort_values(ascending = False)
# Out:
# funding_round_type
# post_ipo_debt            168.704572
# post_ipo_equity           82.182494
# secondary_market          79.649630
# private_equity            73.308593
# undisclosed               19.242370
# debt_financing            17.043526
# venture                   11.748949
# grant                      4.300576
# convertible_note           1.453439
# product_crowdfunding       1.363131
# angel                      0.958694
# seed                       0.719818
# equity_crowdfunding        0.538368
# non_equity_assistance      0.411203
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# # Task 12: Compute average funding amount of angel type
# ### Outcome: Item #2 in Table 2.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 13: Compute average funding amount of seed type
# ### Outcome: Item #3 in Table 2.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 14: Compute average funding amount of private equity venture type
# ### Outcome: Item #4 in Table 2.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 15: Determine most suitable investment type for Spark Funds
# ### Outcome: Item #5 in Table 2.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 16: Compute top 9 countries that have received highest total funding
# ### Outcome: top9 data frame with the top 9 countries

# %%
master_frame
inv_by_country=master_frame.groupby('country_code')
top_9=inv_by_country['raised_amount_usd'].sum().sort_values(ascending = False).head(9)
top_9
# Out:
# country_code
# USA    669482.123821
# CHN     75703.565796
# GBR     32767.048060
# IND     27686.336560
# CAN     18424.675109
# RUS     11279.120120
# DEU     10017.763740
# ISR      9713.884650
# FRA      9059.770757
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# # Task 17: Identify the top 3 English speaking countries in top9 data frame
# ### Outcome: Item #1,2,3 in Table 3.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 18: Map each company's primary sector to one of the 8 main sectors defined in the mappings.csv
# ### Outcome: Merged data frame that maps the primary sector to the main sector

# %%
primary_sector = master_frame['category_list'].str.split("|",expand=True)
master_frame['primary_sector']=primary_sector[0]
mapping_df = pd.read_csv("mapping.csv",encoding = "ISO-8859-1")

df_category_err = mapping_df[(mapping_df['category_list'].str.contains("0",na=False))&(~mapping_df['category_list'].str.contains("2.0",na=False))]
mapping_df.loc[(mapping_df['category_list'].str.contains("0",na=False))&(~mapping_df['category_list'].str.contains("2.0",na=False)),['category_list']] = df_category_err['category_list'].str.replace("0","na")

# %%
#mapping_df.set_index('category_list',inplace=True)
mapping_df.head(200)
# Out:
#                   category_list  Automotive & Sports  Blanks  \
# 0                           NaN                    0       1
# 1                            3D                    0       0
# 2                   3D Printing                    0       0
# 3                 3D Technology                    0       0
# 4                    Accounting                    0       0
# 5              Active Lifestyle                    0       0
# 6                  Ad Targeting                    0       0
# 7            Advanced Materials                    0       0
# 8              Adventure Travel                    1       0
# 9                   Advertising                    0       0
# 10        Advertising Exchanges                    0       0
# 11         Advertising Networks                    0       0
# 12        Advertising Platforms                    0       0
# 13                       Advice                    0       0
# ...

# %%
def map_sector(sector):
    if mapping_df.index.contains(sector):
        return mapping_df.loc[sector][lambda x: x == 1].index[0]
    else:
        return "Others"

master_frame['main_sector']=list(map(map_sector,master_frame['primary_sector']))
# Out:
# ['Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
#  'Others',
# ...

# %%
d = master_frame[['primary_sector','main_sector']]
e = d.drop_duplicates()
e.shape
# Out:
# (716, 2)

# %%
z = master_frame.loc[(master_frame['country_code'].isin(['USA','GBR','IND'])) & (master_frame['funding_round_type']=='venture') & (master_frame['raised_amount_usd'] >=5000000) & (master_frame['raised_amount_usd'] <=15000000),:]
z.groupby(['country_code','main_sector']).company_permalink.count()
# Out:
# country_code  main_sector
# GBR           Automotive & Sports                          16
#               Blanks                                        7
#               Cleantech / Semiconductors                  128
#               Entertainment                                56
#               Health                                       24
#               Manufacturing                                42
#               News, Search and Messaging                   73
#               Others                                      149
#               Social, Finance, Analytics, Advertising     133
# IND           Automotive & Sports                          13
#               Blanks                                        2
#               Cleantech / Semiconductors                   20
#               Entertainment                                33
#               Health                                       19
#               Manufacturing                                21
# ...

# %% [markdown]
# # Task 19: Compute the most heavily invested main sector in each of the 3 countries (identified in Task 17) for the selected funding type (identifed in Task 15) and investments in the range of 5 - 15 million USD
# ### Outcome: 3 separate data frames for - one for each of the 3 countries containing observations for the selected funding type falling within the 5 - 15 million USD range.

# %%
D1=master_frame.loc[(master_frame['country_code'] =='USA') & (master_frame['funding_round_type']=='venture') & (master_frame['raised_amount_usd'] >=5000000) & (master_frame['raised_amount_usd'] <=15000000),:]

D1['inv_count_by_sector'] = D1.groupby('main_sector').main_sector.transform('count')
D1['total_inv_by_sector'] = D1.groupby('main_sector').raised_amount_usd.transform('sum')
D1.sort_values(by='inv_count_by_sector',ascending=False,inplace=True)
D1.head()
# Out:
#                 company_permalink  \
# 29312           /organization/dtt
# 31959         /organization/engim
# 31478    /organization/employease
# 86398  /organization/sciencelogic
# 86390    /organization/science-37
#
#                                funding_round_permalink funding_round_type  \
# 29312  /funding-round/c540310c185ba8218dec300b34b0c6b4            venture
# 31959  /funding-round/cf05fa1293c266b1563bf3581c106853            venture
# 31478  /funding-round/85aa7fa38264125006f1b766ad07071d            venture
# 86398  /funding-round/3d13784304defa28ee864c41fa636dfd            venture
# 86390  /funding-round/7b8054e63d61c3ccdfa42763de8bf98c            venture
#
#       funding_round_code   funded_at  raised_amount_usd          name  \
# 29312                NaN  10-06-2009          7000000.0           DTT
# 31959                  A  01-01-2001         12920000.0         Engim
# 31478                  C  26-10-2001         10000000.0    Employease
# ...

# %%
D1=master_frame.loc[(master_frame['country_code'] =='USA') & (master_frame['funding_round_type']=='venture') & (master_frame['raised_amount_usd'] >=5) & (master_frame['raised_amount_usd'] <=15),:]

D1['inv_count_by_sector'] = D1.groupby('main_sector').main_sector.transform('count')
D1['total_inv_by_sector'] = D1.groupby('main_sector').raised_amount_usd.transform('sum')
D1.sort_values(by='inv_count_by_sector',ascending=False,inplace=True)


D2=master_frame.loc[(master_frame['country_code'] =='GBR') & (master_frame['funding_round_type']=='venture') & (master_frame['raised_amount_usd'] >=5) & (master_frame['raised_amount_usd'] <=15),:]

D2['inv_count_by_sector'] = D2.groupby('main_sector').main_sector.transform('count')
D2['total_inv_by_sector'] = D2.groupby('main_sector').raised_amount_usd.transform('sum')
D2.sort_values(by='inv_count_by_sector',ascending=False,inplace=True)

D3=master_frame.loc[(master_frame['country_code'] =='IND') & (master_frame['funding_round_type']=='venture') & (master_frame['raised_amount_usd'] >=5) & (master_frame['raised_amount_usd'] <=15),:]

D3['inv_count_by_sector'] = D3.groupby('main_sector').main_sector.transform('count')
D3['total_inv_by_sector'] = D3.groupby('main_sector').raised_amount_usd.transform('sum')
D3.sort_values(by='inv_count_by_sector',ascending=False,inplace=True)

#D1.head()
#D2.head()
#D3.head()

print("Total # of investments in USA is ",D1.inv_count_by_sector.sum())
print("Total amount of investments in USA is ",D1.total_inv_by_sector.sum())

print("Total # of investments in GBR is ",D2.inv_count_by_sector.sum())
print("Total amount of investments in GBR is ",D2.total_inv_by_sector.sum())

print("Total # of investments in IND is ",D3.inv_count_by_sector.sum())
print("Total amount of investments in IND is ",D3.total_inv_by_sector.sum())

# Table 5.1 Qs 9: For point 3 (top sector count-wise), which company received the highest investment?
D1[D1.main_sector=='Others'].groupby(['main_sector','company_permalink']).total_inv_by_sector.sum().sort_values(ascending=False)
D2[D2.main_sector=='Others'].groupby(['main_sector','company_permalink']).total_inv_by_sector.sum().sort_values(ascending=False)
D3[D3.main_sector=='Others'].groupby(['main_sector','company_permalink']).total_inv_by_sector.sum().sort_values(ascending=False)


D1[D1.main_sector=='Social, Finance, Analytics, Advertising'].groupby(['main_sector','company_permalink']).total_inv_by_sector.sum().sort_values(ascending=False)
D2[D2.main_sector=='Social, Finance, Analytics, Advertising'].groupby(['main_sector','company_permalink']).total_inv_by_sector.sum().sort_values(ascending=False)
D3[D3.main_sector=='Social, Finance, Analytics, Advertising'].groupby(['main_sector','company_permalink']).total_inv_by_sector.sum().sort_values(ascending=False)
# Out:
# Total # of investments in USA is  26019772
# Total amount of investments in USA is  232420325.2524099
# Total # of investments in GBR is  67384
# Total amount of investments in GBR is  580845.3292150002
# Total # of investments in IND is  20868
# Total amount of investments in IND is  188882.06511
# main_sector                              company_permalink
# Social, Finance, Analytics, Advertising  /organization/manthan-systems                                 2202.19820
#                                          /organization/komli-media                                     1651.64865
#                                          /organization/microland                                       1101.09910
#                                          /organization/grameen-financial-services                      1101.09910
#                                          /organization/shopclues-com                                   1101.09910
# ...

# %% [markdown]
# # Task 20: Determine the main sectors and countries Sparks Funds should invest by filling up Table 5.1 of excel sheet
# ### Outcome: Filled up Table 5.1 in excel sheet

# %% [markdown]
# # Task 21: Create a plot showing the fraction of total investments (globally) in venture, seed, and private equity, and the average amount of investment in each funding type
# ### Outcome: Tableau plot

# %%
# Insert code to export data for use in Tableau??

# %% [markdown]
# # Task 22: Create a plot showing the top 9 countries against the total amount of investments for the selected funding type
# ### Outcome: Tableau plot

# %%
# Insert code to export data for use in Tableau??

# %% [markdown]
# # Task 23: A plot showing the number of investments in the top 3 sectors of the top 3 countries on one chart for the selected investment type
# ### Outcome: Tableau Plot

# %%
# Insert code to export data for use in Tableau??
