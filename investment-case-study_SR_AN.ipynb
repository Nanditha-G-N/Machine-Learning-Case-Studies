# %%
# Investment case study python file
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')



# Import the numpy and pandas packages

import numpy as np
import pandas as pd
import PyPDF2 as pdf

# %% [markdown]
# # Task 1 : Load companies data into companies data frame

# %%
companies = pd.read_csv("companies.txt",sep='\t',encoding="ISO-8859-1",header=(0)) # code for importing the companies.csv file. ipynb file and the source file in the same location 
companies
# Out:
#                                                permalink  \
# 0                                    /Organization/-Fame
# 1                                 /Organization/-Qounter
# 2                    /Organization/-The-One-Of-Them-Inc-
# 3                                  /Organization/0-6-Com
# 4                         /Organization/004-Technologies
# 5                       /Organization/01Games-Technology
# 6                    /Organization/0Ndine-Biomedical-Inc
# 7                                   /Organization/0Xdata
# 8                                        /Organization/1
# 9                              /Organization/1-2-3-Listo
# 10                                 /Organization/1-4-All
# 11                        /Organization/1-618-Technology
# 12                           /Organization/1-800-Dentist
# 13                           /Organization/1-800-Doctors
# 14              /Organization/1-800-Publicrelations-Inc-
# ...

# %% [markdown]
# # Task 2: Load rounds data into rounds2 data frame

# %%
rounds2 = pd.read_csv("rounds2.csv",encoding="ISO-8859-1",header=(0)) # code for importing the rounds2.csv file. ipynb file and the source file in the same location 
rounds2
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /organization/-qounter
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /organization/0-6-com
# 5                          /ORGANIZATION/004-TECHNOLOGIES
# 6                        /organization/01games-technology
# 7                     /ORGANIZATION/0NDINE-BIOMEDICAL-INC
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /ORGANIZATION/0XDATA
# 10                                   /organization/0xdata
# 11                                   /ORGANIZATION/0XDATA
# 12                                   /organization/0xdata
# 13                                        /ORGANIZATION/1
# 14                                        /organization/1
# ...

# %% [markdown]
# # Task 10: Resolve encoding issues
# ### Outcome: upddated rounds2 and companies file

# %%
rounds2['company_permalink'] = rounds2.company_permalink.str.encode('utf-8').str.decode('ascii', 'ignore')
rounds2
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /organization/-qounter
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /organization/0-6-com
# 5                          /ORGANIZATION/004-TECHNOLOGIES
# 6                        /organization/01games-technology
# 7                     /ORGANIZATION/0NDINE-BIOMEDICAL-INC
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /ORGANIZATION/0XDATA
# 10                                   /organization/0xdata
# 11                                   /ORGANIZATION/0XDATA
# 12                                   /organization/0xdata
# 13                                        /ORGANIZATION/1
# 14                                        /organization/1
# ...

# %%
companies['permalink'] = companies.permalink.str.encode('utf-8').str.decode('ascii', 'ignore')
companies['name'] = companies.name.str.encode('utf-8').str.decode('ascii', 'ignore')
companies
# Out:
#                                                permalink  \
# 0                                    /Organization/-Fame
# 1                                 /Organization/-Qounter
# 2                    /Organization/-The-One-Of-Them-Inc-
# 3                                  /Organization/0-6-Com
# 4                         /Organization/004-Technologies
# 5                       /Organization/01Games-Technology
# 6                    /Organization/0Ndine-Biomedical-Inc
# 7                                   /Organization/0Xdata
# 8                                        /Organization/1
# 9                              /Organization/1-2-3-Listo
# 10                                 /Organization/1-4-All
# 11                        /Organization/1-618-Technology
# 12                           /Organization/1-800-Dentist
# 13                           /Organization/1-800-Doctors
# 14              /Organization/1-800-Publicrelations-Inc-
# ...

# %% [markdown]
# ### Testing: upddated rounds2 and companies file

# %%
companies[companies['homepage_url']=='http://inovatiff.com']
# Out:
#                                                permalink  \
# 66367  /Organization/Novatiff-Reklam-Ve-TanTM-Hizmetl...
#
#                                           name          homepage_url  \
# 66367  novatiff Reklam ve Tantm Hizmetleri Tic  http://inovatiff.com
#
#                             category_list     status country_code state_code  \
# 66367  Consumer Goods|E-Commerce|Internet  operating          NaN        NaN
#
#       region city founded_at
# 66367    NaN  NaN        NaN

# %% [markdown]
# # Task 3: Extract list of countries from PDF where English is an official language -- Yet to complete

# %%
# reading the pdf file
pdf_object = open('Countries_where_English_is_an_official_language.pdf', 'rb')
pdfobject = pdf.PdfFileReader(pdf_object)
countries = pdfobject.getPage(0).extractText()
countries.split('\n')
# Out:
# ['ListofcountrieswhereEnglishisanofficiallanguage',
#  'AfricaBotswanaCameroonEthiopiaEritrea',
#  'TheGambiaGhanaKenyaLesothoLiberiaMalawiMauritiusNamibiaNigeriaRwandaSeychellesSierraLeone',
#  'SouthAfricaSouthSudanSudanSwazilandTanzaniaUgandaZambiaZimbabwe',
#  'AmericasAntiguaandBarbudaTheBahamas',
#  'BarbadosBelizeCanadaDominicaGrenadaGuyanaJamaicaSaintKittsandNevisSaintLuciaSaintVincentandtheGrenadinesTrinidadandTobago',
#  'UnitedStates',
#  '',
#  'AsiaIndiaPakistanPhilippinesSingaporeAustralia/OceaniaAustraliaFijiKiribatiMarshallIslandsFederatedStates',
#  'ofMicronesiaNauruNewZealand',
#  'PalauPapuaNewGuineaSamoaSolomonIslands',
#  'TongaTuvaluVanuatu',
#  'EuropeIrelandMaltaUnitedKingdom',
#  '']

# %% [markdown]
# # Task 4: Compute no. of unique companies in round2
# ### Outcome: Item #1 in Table 1.1 of excel sheet

# %%
rounds2['company_permalink'] = rounds2['company_permalink'].str.lower()
rounds2['company_permalink'] = rounds2['company_permalink'].str.strip()
rounds2.shape #114949 total rows
rounds2['company_permalink'].unique().shape # 66370 unique companies
# Out:
# (66368,)

# %% [markdown]
# # Task 5: Compute no. of unique companies in companies
# ### Outcome: Item #2 in Table 1.1 of excel sheet

# %%
companies['permalink'] = companies['permalink'].str.lower()
companies['permalink'] = companies['permalink'].str.strip()
companies.shape #66368 total rows
companies['permalink'].unique().shape # 66368 unique companies
# Out:
# (66368,)

# %% [markdown]
# # Task 6: Identify column in companies df that can be used as unique key for each company
# ### Outcome: Item #3 in Table 1.1 of excel sheet

# %%
companies.columns
rounds2.columns
# Out:
# Index(['company_permalink', 'funding_round_permalink', 'funding_round_type',
#        'funding_round_code', 'funded_at', 'raised_amount_usd'],
#       dtype='object')

# %% [markdown]
# # Task 7: Check if there are companies in round2 that are not in companies
# ### Outcome: Item #4 in Table 1.1 of excel sheet

# %%
rounds2[~rounds2['company_permalink'].isin(companies['permalink'])] # 7 companies 
#companies[~companies['permalink'].isin(rounds2['company_permalink'])].shape # 5 companies
# Out:
# Empty DataFrame
# Columns: [company_permalink, funding_round_permalink, funding_round_type, funding_round_code, funded_at, raised_amount_usd]
# Index: []

# %% [markdown]
# # Task 8: Merge companies & round2 data frames into master_frame df and compute total no. of observations in master_frame
# ### Outcome: Item#5 in Table 1.1 of excel sheet; master_frame data frame"

# %%
master_frame = pd.merge(rounds2, companies, left_on = 'company_permalink', right_on = 'permalink', how='inner')
master_frame.shape # 114949
# Out:
# (114949, 16)

# %% [markdown]
# # Task 11: Compute average funding amount of venture type
# ### Outcome: Item #1 in Table 2.1 of excel sheet

# %%
master_frame.funding_round_type.unique()
master_frame.columns
# Out:
# Index(['company_permalink', 'funding_round_permalink', 'funding_round_type',
#        'funding_round_code', 'funded_at', 'raised_amount_usd', 'permalink',
#        'name', 'homepage_url', 'category_list', 'status', 'country_code',
#        'state_code', 'region', 'city', 'founded_at'],
#       dtype='object')

# %%
master_frame.raised_amount_usd.describe()
master_frame.raised_amount_usd.isnull().sum()
# Out:
# 19990

# %% [markdown]
# ### Drop null 17% rows where raised_amount_usd isnull

# %%
master_frame = master_frame[~master_frame.raised_amount_usd.isnull()]
master_frame.shape
# Out:
# (94959, 16)

# %%
#master_frame.loc[pd.isnull(master_frame['raised_amount_usd']), ['raised_amount_usd']] = master_frame['raised_amount_usd'].describe()[6]

# %%
funding_grp = master_frame.groupby('funding_round_type')

# %%
funding_grp['raised_amount_usd'].mean()/1000000
# Out:
# funding_round_type
# angel                      0.958694
# convertible_note           1.453439
# debt_financing            17.043526
# equity_crowdfunding        0.538368
# grant                      4.300576
# non_equity_assistance      0.411203
# post_ipo_debt            168.704572
# post_ipo_equity           82.182494
# private_equity            73.308593
# product_crowdfunding       1.363131
# secondary_market          79.649630
# seed                       0.719818
# undisclosed               19.242370
# venture                   11.748949
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# # Task 12: Compute average funding amount of angel type
# ### Outcome: Item #2 in Table 2.1 of excel sheet

# %%
# NA... refer above

# %% [markdown]
# # Task 13: Compute average funding amount of seed type
# ### Outcome: Item #3 in Table 2.1 of excel sheet

# %%
# NA... refer above

# %% [markdown]
# # Task 14: Compute average funding amount of private equity venture type
# ### Outcome: Item #4 in Table 2.1 of excel sheet

# %%
# NA... refer above

# %% [markdown]
# # Task 15: Determine most suitable investment type for Spark Funds
# ### Outcome: Item #5 in Table 2.1 of excel sheet

# %%
# venture type
# updating master dataframe for funding_round_type = venture
master_frame = master_frame[master_frame['funding_round_type']=='venture']
master_frame
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 8                     /organization/0ndine-biomedical-inc
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 22                             /organization/1-mainstream
# 28                          /organization/10-minutes-with
# 34                             /organization/1000memories
# 38                          /organization/1000museums-com
# 39                          /organization/1000museums-com
# 41                          /organization/1000museums-com
# 44                          /organization/1000museums-com
# 46                               /organization/1001-menus
# ...

# %% [markdown]
# # Task 16: Compute top 9 countries that have received highest total funding
# ### Outcome: top9 data frame with the top 9 countries

# %%
top_country_grp = master_frame.groupby('country_code') 

top_country_grp['raised_amount_usd'].sum().sort_values(ascending = False).head(9)/1000000
# Out:
# country_code
# USA    422510.842796
# CHN     39835.418773
# GBR     20245.627416
# IND     14391.858718
# CAN      9583.332317
# FRA      7259.536732
# ISR      6907.514579
# DEU      6346.959822
# JPN      3363.676611
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# # Task 17: Identify the top 3 English speaking countries in top9 data frame
# ### Outcome: Item #1,2,3 in Table 3.1 of excel sheet

# %%
# USA, GBR & IND from the above code

# %% [markdown]
# # Task 18: Map each company's primary sector to one of the 8 main sectors defined in the mappings.csv
# ### Outcome: Merged data frame that maps the primary sector to the main sector

# %%
master_frame = master_frame[master_frame['country_code'].isin(['USA','GBR','IND'])]
master_frame.country_code.unique()
# Out:
# array(['IND', 'USA', 'GBR'], dtype=object)

# %%
master_frame["top_category"] = master_frame['category_list'].str.split("|", n = 1, expand = True)[0]
master_frame.top_category.unique()
# Out:
# array(['Media', 'Analytics', 'Apps', 'Education', 'Curated Web',
#        'Health Care', 'Software', 'Biotechnology', 'Enterprise Software',
#        'Service Providers', 'Manufacturing', 'Advertising', 'Internet',
#        'Clean Technology', 'Health and Wellness', 'E-Commerce', 'News',
#        'Art', 'Big Data', 'Finance', 'EdTech', 'Computers',
#        'Cloud Computing', 'Hardware + Software', 'Internet of Things',
#        'Cloud Infrastructure', 'Messaging', 'Information Technology',
#        'Consumer Electronics', 'Data Centers', 'Android',
#        'Customer Service', '3D Technology', '3D', 'Games', 'Drones',
#        '3D Printing', 'Automated Kiosk', 'Music', 'Web Hosting',
#        'Cloud Data Services', 'Consulting', nan, 'Physical Security',
#        'Security', 'Databases', 'Flash Storage', 'Machine Learning',
#        'Commercial Real Estate', 'Anything Capital Intensive',
#        'Automotive', 'Ad Targeting', 'Office Space', 'Online Shopping',
# ...

# %%
df_mapping = pd.read_csv("mapping.csv")
df_category_err = df_mapping[(df_mapping['category_list'].str.contains("0",na=False))&(~df_mapping['category_list'].str.contains("2.0",na=False))]
df_mapping.loc[(df_mapping['category_list'].str.contains("0",na=False))&(~df_mapping['category_list'].str.contains("2.0",na=False)),['category_list']] = df_category_err['category_list'].str.replace("0","na")

# %%
df_mapping[df_mapping['category_list'].str.contains("2.0",na=False)]
# Out:
#       category_list  Automotive & Sports  Blanks  Cleantech / Semiconductors  \
# 243  Enterprise 2.0                    0       0                           0
#
#      Entertainment  Health  Manufacturing  News, Search and Messaging  Others  \
# 243              0       0              0                           0       1
#
#      Social, Finance, Analytics, Advertising
# 243                                        0

# %%
column_value = np.array(df_mapping.columns.tolist())
column_value = column_value.reshape(1,10)
df_mapping_list = pd.melt(df_mapping, id_vars=['category_list'], value_vars=print(column_value))
#df_mapping_list
df_mapping_list = df_mapping_list[df_mapping_list["value"]==1]
df_mapping_list
# Out:
# [['category_list' 'Automotive & Sports' 'Blanks'
#   'Cleantech / Semiconductors' 'Entertainment' 'Health' 'Manufacturing'
#   'News, Search and Messaging' 'Others'
#   'Social, Finance, Analytics, Advertising']]
#                  category_list                                 variable  value
# 8             Adventure Travel                      Automotive & Sports      1
# 14                   Aerospace                      Automotive & Sports      1
# 45                        Auto                      Automotive & Sports      1
# 46             Automated Kiosk                      Automotive & Sports      1
# 47                  Automotive                      Automotive & Sports      1
# 57                    Bicycles                      Automotive & Sports      1
# 69            Boating Industry                      Automotive & Sports      1
# 87                         CAD                      Automotive & Sports      1
# ...

# %%
df_mapping_list["sector"] = df_mapping_list["variable"] 
df_mapping_list = df_mapping_list.drop(["variable","value"],axis=1)
df_mapping_list[df_mapping_list["category_list"]=='natural gas Uses']
# Out:
# Empty DataFrame
# Columns: [category_list, sector]
# Index: []

# %%
master_frame.columns
# Out:
# Index(['company_permalink', 'funding_round_permalink', 'funding_round_type',
#        'funding_round_code', 'funded_at', 'raised_amount_usd', 'permalink',
#        'name', 'homepage_url', 'category_list', 'status', 'country_code',
#        'state_code', 'region', 'city', 'founded_at', 'top_category'],
#       dtype='object')

# %%
master_frame.top_category.unique().shape
df_mapping_list
master_frame[~master_frame['top_category'].str.lower().isin(df_mapping_list['category_list'].str.lower())].top_category.unique()
# Out:
# array(['Natural Gas Uses', 'Adaptive Equipment', 'Racing',
#        'Specialty Retail', 'Biotechnology and Semiconductor',
#        'Rapidly Expanding', 'Product Search', 'GreenTech', 'Retirement'],
#       dtype=object)

# %%
master_frame.columns
# Out:
# Index(['company_permalink', 'funding_round_permalink', 'funding_round_type',
#        'funding_round_code', 'funded_at', 'raised_amount_usd', 'permalink',
#        'name', 'homepage_url', 'category_list', 'status', 'country_code',
#        'state_code', 'region', 'city', 'founded_at', 'top_category'],
#       dtype='object')

# %%
df_mapping_list.columns
# Out:
# Index(['category_list', 'sector'], dtype='object')

# %%
# merge Master dataframe to mapping list to map category to sector
master_frame = pd.merge(master_frame, df_mapping_list, left_on = master_frame['top_category'].str.strip().str.lower(), right_on = df_mapping_list['category_list'].str.strip().str.lower(), how='left')

# %%
df_mapping_list.sector.unique()
# Out:
# array(['Automotive & Sports', 'Blanks', 'Cleantech / Semiconductors',
#        'Entertainment', 'Health', 'Manufacturing',
#        'News, Search and Messaging', 'Others',
#        'Social, Finance, Analytics, Advertising'], dtype=object)

# %%
#Assign missing categories in main data frame to Blanks Sector
master_frame.columns
# Out:
# Index(['key_0', 'company_permalink', 'funding_round_permalink',
#        'funding_round_type', 'funding_round_code', 'funded_at',
#        'raised_amount_usd', 'permalink', 'name', 'homepage_url',
#        'category_list_x', 'status', 'country_code', 'state_code', 'region',
#        'city', 'founded_at', 'top_category', 'category_list_y', 'sector'],
#       dtype='object')

# %%
master_frame[master_frame.sector.isnull()]
# Out:
# Empty DataFrame
# Columns: [key_0, company_permalink, funding_round_permalink, funding_round_type, funding_round_code, funded_at, raised_amount_usd, permalink, name, homepage_url, category_list_x, status, country_code, state_code, region, city, founded_at, top_category, category_list_y, sector]
# Index: []

# %%
master_frame.loc[pd.isnull(master_frame['sector']), ['sector']] = 'Blanks'

# %%
master_frame[master_frame.sector.isnull()]
# Out:
# Empty DataFrame
# Columns: [key_0, company_permalink, funding_round_permalink, funding_round_type, funding_round_code, funded_at, raised_amount_usd, permalink, name, homepage_url, category_list_x, status, country_code, state_code, region, city, founded_at, top_category, category_list_y, sector]
# Index: []

# %% [markdown]
# # Task 19: Compute the most heavily invested main sector in each of the 3 countries (identified in Task 17) for the selected funding type (identifed in Task 15) and investments in the range of 5 - 15 million USD
# ### Outcome: 3 separate data frames for - one for each of the 3 countries containing observations for the selected funding type falling within the 5 - 15 million USD range.

# %%
master_frame_USA = master_frame[master_frame['country_code']=='USA']
master_frame_GBR = master_frame[master_frame['country_code']=='GBR']
master_frame_IND = master_frame[master_frame['country_code']=='IND']

# %%
top_sector_grp_USA = master_frame_USA.groupby('sector')
top_sector_grp_GBR = master_frame_GBR.groupby('sector')
top_sector_grp_IND = master_frame_IND.groupby('sector')

# %%
top_sector_grp_USA['raised_amount_usd'].sum().sort_values(ascending = False).head(9)/1000000
# Out:
# sector
# Cleantech / Semiconductors                 119931.874301
# Social, Finance, Analytics, Advertising     86331.402349
# Others                                      82822.211972
# News, Search and Messaging                  45600.521085
# Health                                      31675.057766
# Manufacturing                               24845.319470
# Entertainment                               17014.560960
# Automotive & Sports                         11632.164696
# Blanks                                       2657.730197
# Name: raised_amount_usd, dtype: float64

# %%
top_sector_grp_GBR['raised_amount_usd'].sum().sort_values(ascending = False).head(9)/1000000
# Out:
# sector
# Cleantech / Semiconductors                 5073.290093
# Others                                     4492.219646
# Social, Finance, Analytics, Advertising    3773.328672
# News, Search and Messaging                 2956.023749
# Entertainment                              1162.564878
# Health                                     1046.654806
# Manufacturing                              1019.283214
# Automotive & Sports                         480.878712
# Blanks                                      241.383646
# Name: raised_amount_usd, dtype: float64

# %%
top_sector_grp_IND['raised_amount_usd'].sum().sort_values(ascending = False).head(9)/1000000
# Out:
# sector
# Others                                     6329.507440
# News, Search and Messaging                 1739.579948
# Social, Finance, Analytics, Advertising    1578.804920
# Automotive & Sports                        1556.350000
# Entertainment                               976.191777
# Cleantech / Semiconductors                  786.444633
# Manufacturing                               730.260000
# Health                                      564.370000
# Blanks                                      130.350000
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# # Task 20: Determine the main sectors and countries Sparks Funds should invest by filling up Table 5.1 of excel sheet
# ### Outcome: Filled up Table 5.1 in excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 21: Create a plot showing the fraction of total investments (globally) in venture, seed, and private equity, and the average amount of investment in each funding type
# ### Outcome: Tableau plot

# %%
# Insert code to export data for use in Tableau??

# %% [markdown]
# # Task 22: Create a plot showing the top 9 countries against the total amount of investments for the selected funding type
# ### Outcome: Tableau plot

# %%
# Insert code to export data for use in Tableau??

# %% [markdown]
# # Task 23: A plot showing the number of investments in the top 3 sectors of the top 3 countries on one chart for the selected investment type
# ### Outcome: Tableau Plot

# %%
# Insert code to export data for use in Tableau??
