# %%
# Investment case study python file
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# # Task 1 : Load companies data into companies data frame

# %%
companies = pd.read_csv("companies.txt", sep="\t",encoding = "ISO-8859-1")
companies['permalink']=companies['permalink'].str.lower()
companies['permalink']=companies['permalink'].str.strip()
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# 3                                        Curated Web  operating          CHN
# 4                                           Software  operating          USA
#
#   state_code                 region           city  founded_at
# 0         16                 Mumbai         Mumbai         NaN
# 1         DE             DE - Other  Delaware City  04-09-2014
# 2        NaN                    NaN            NaN         NaN
# 3         22                Beijing        Beijing  01-01-2007
# 4         IL  Springfield, Illinois      Champaign  01-01-2010

# %% [markdown]
# # Task 2: Load rounds data into rounds2 data frame

# %%
rounds2 = pd.read_csv("rounds2.csv",encoding = "ISO-8859-1")
rounds2['company_permalink']=rounds2['company_permalink'].str.lower()
rounds2['company_permalink']=rounds2['company_permalink'].str.strip()
rounds2.info()
rounds2.describe()
rounds2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 6 columns):
# company_permalink          114949 non-null object
# funding_round_permalink    114949 non-null object
# funding_round_type         114949 non-null object
# funding_round_code         31140 non-null object
# funded_at                  114949 non-null object
# raised_amount_usd          94959 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 5.3+ MB
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /organization/-qounter
# 2               /organization/-qounter
# 3  /organization/-the-one-of-them-inc-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# 4                  A  19-03-2008          2000000.0

# %% [markdown]
# # Task 4: Compute no. of unique companies in round2
# ### Outcome: Item #1 in Table 1.1 of excel sheet

# %%
rounds2.company_permalink.unique().size
# Out:
# 66370

# %% [markdown]
# # Task 5: Compute no. of unique companies in companies
# ### Outcome: Item #2 in Table 1.1 of excel sheet

# %%
companies.permalink.unique().size
# Out:
# 66368

# %% [markdown]
# # Task 6: Identify column in companies df that can be used as unique key for each company
# ### Outcome: Item #3 in Table 1.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 7: Check if there are companies in round2 that are not in companies
# ### Outcome: Item #4 in Table 1.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 8: Resolve encoding issue in permalink column
# ### Outcome: Updated master_frame data frame

# %%
#Removing the encoded values from the comany permalink column
companies.permalink=companies.permalink.str.encode('utf-8').str.decode('ascii', 'ignore')
rounds2.company_permalink=rounds2.company_permalink.str.encode('utf-8').str.decode('ascii', 'ignore')
companies.head()
print("Rounds2 data:",rounds2.company_permalink.unique().size)
print("companies data:",companies.permalink.unique().size)
# Out:
# Rounds2 data: 66368
# companies data: 66368

# %%
rounds2.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /organization/-qounter
# 2               /organization/-qounter
# 3  /organization/-the-one-of-them-inc-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# 4                  A  19-03-2008          2000000.0

# %% [markdown]
# # Task 9: Merge companies & round2 data frames into master_frame df and compute total no. of observations in master_frame
# ### Outcome: Item#5 in Table 1.1 of excel sheet; master_frame data frame"

# %%
companies.rename(columns={'permalink': 'company_permalink'},inplace=True)
master_frame=pd.merge(rounds2, companies, how='left', on='company_permalink')
master_frame.raised_amount_usd.sort_values(ascending = False)
master_frame.loc[pd.isnull(master_frame['raised_amount_usd']), ['raised_amount_usd']]=7000000
master_frame['raised_amount_usd']=master_frame['raised_amount_usd']/1000000
master_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114949 entries, 0 to 114948
# Data columns (total 15 columns):
# company_permalink          114949 non-null object
# funding_round_permalink    114949 non-null object
# funding_round_type         114949 non-null object
# funding_round_code         31140 non-null object
# funded_at                  114949 non-null object
# raised_amount_usd          114949 non-null float64
# name                       114948 non-null object
# homepage_url               108815 non-null object
# category_list              111539 non-null object
# status                     114949 non-null object
# country_code               106271 non-null object
# state_code                 104003 non-null object
# region                     104782 non-null object
# city                       104785 non-null object
# founded_at                 94428 non-null object
# dtypes: float64(1), object(14)
# memory usage: 14.0+ MB

# %%
master_frame
inv_by_funding_type=master_frame.groupby('funding_round_type')

# %% [markdown]
# # Task 10: Resolve encoding issue in company_permalink
# ### Outcome: Updated master_frame data frame

# %%
master_frame
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 5                          /organization/004-technologies
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 14                                        /organization/1
# 15                                        /organization/1
# 16                              /organization/1-2-3-listo
# 17                                  /organization/1-4-all
# 18                         /organization/1-618-technology
# 19                            /organization/1-800-dentist
# 20                            /organization/1-800-doctors
# 21               /organization/1-800-publicrelations-inc-
# 22                             /organization/1-mainstream
# 23                                  /organization/1-of-99
# 24                              /organization/10-20-media
# 25                              /organization/10-20-media
# 26                              /organization/10-20-media
# 27                              /organization/10-20-media
# 28                          /organization/10-minutes-with
# 29                          /organization/10-minutes-with
# ...                                                   ...
# 114919                              /organization/zynstra
# 114920                           /organization/zyomyx-inc
# 114921                           /organization/zyomyx-inc
# 114922                           /organization/zyomyx-inc
# 114923                           /organization/zyomyx-inc
# 114924                                 /organization/zype
# 114925                                 /organization/zype
# 114926                               /organization/zypsee
# 114927                               /organization/zypsee
# 114928                     /organization/zyraz-technology
# 114929                     /organization/zyraz-technology
# 114930                     /organization/zyraz-technology
# 114931                     /organization/zyraz-technology
# 114932                                /organization/zyrra
# 114933                                /organization/zyrra
# 114934                                /organization/zyrra
# 114935                                /organization/zyrra
# 114936                               /organization/zystor
# 114937                           /organization/zytoprotec
# 114938                                /organization/zzish
# 114939                                /organization/zzish
# 114940                                /organization/zzish
# 114941  /organization/zznode-science-and-technology-co...
# 114942                          /organization/zzzzapp-com
# 114943                          /organization/zzzzapp-com
# 114944                          /organization/zzzzapp-com
# 114945                          /organization/zzzzapp-com
# 114946                                 /organization/eron
# 114947                               /organization/asys-2
# 114948  /organization/novatiff-reklam-ve-tantm-hizmetl...
#
#                                 funding_round_permalink   funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638              venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633              venture
# 2       /funding-round/b44fbb94153f6cdef13083530bb48030                 seed
# 3       /funding-round/650b8f704416801069bb178a1418776b              venture
# 4       /funding-round/5727accaeaa57461bd22a9bdd945382d              venture
# 5       /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830              venture
# 6       /funding-round/7d53696f2b4f607a2f2a8cbb83d01839          undisclosed
# 7       /funding-round/2b9d3ac293d5cdccbecff5c8cb0f327d                 seed
# 8       /funding-round/954b9499724b946ad8c396a57a5f3b72              venture
# 9       /funding-round/383a9bd2c04f7038bb543ccef5ba3eae                 seed
# 10      /funding-round/3bb2ee4a2d89251a10aaa735b1180e44              venture
# 11      /funding-round/ae2a174c06517c2394aed45006322a7e              venture
# 12      /funding-round/e1cfcbe1bdf4c70277c5f29a3482f24e              venture
# 13      /funding-round/03b975068632eba5bfdb937ec8c07a68                 seed
# 14      /funding-round/5de6d8828aef7d925d97918d15727670          undisclosed
# 15      /funding-round/e82464f22241715dd1a6c77241055ed1                 seed
# 16      /funding-round/6de4609e894495105bc791ed64361288                 seed
# 17      /funding-round/e97a192e13ea0ee3c4f71136b4f3ec16  equity_crowdfunding
# 18      /funding-round/83b8f4c7d37ecef5e001a5e953bf461a  equity_crowdfunding
# 19      /funding-round/5274aacc211163fc7c86539ce94bbacc          undisclosed
# 20      /funding-round/9eb8c7790a0c200d79e75785d1c4aa12     convertible_note
# 21      /funding-round/11c228f58831bc7ed337ef69ecc560c2       private_equity
# 22      /funding-round/b952cbaf401f310927430c97b68162ea              venture
# 23      /funding-round/b5c811f561cfb5701cd5b1762120bbc3     convertible_note
# 24      /funding-round/436874dc54b54460f99f44c06e50990a       debt_financing
# 25      /funding-round/8025ee9c11a586eac4a234ddec7beb30       debt_financing
# 26      /funding-round/a884bf8326b9fd59789c0f74a28dbc3b       debt_financing
# 27      /funding-round/d205f5416ce55e126beda3ed2bf2c2cd       debt_financing
# 28      /funding-round/0faccbbcc5818dc5326469f13f5a8ac8              venture
# 29      /funding-round/f245a74b4c54610ae843e17bdf4d1113                 seed
# ...                                                 ...                  ...
# 114919  /funding-round/dee233b3434185c14b3352034f72d798                angel
# 114920  /funding-round/4191cb5258d3863b0212d1083881da64              venture
# 114921  /funding-round/85443f5438bfd50104b9591eabc95c94                grant
# 114922  /funding-round/b4fce7f8a13267353d57db09099800e8              venture
# 114923  /funding-round/ea5b21da6cf999ff4d5667431fe318d7              venture
# 114924  /funding-round/24e8134882bf6c4dcc385abba0acd5d9                 seed
# 114925  /funding-round/c9f5097b3617c7539aa47c8b448163be                 seed
# 114926  /funding-round/472c6f7940522552fcca465b8cd3deef                 seed
# 114927  /funding-round/c67e22c5448435adaf5a2d101e449dde                 seed
# 114928  /funding-round/3c3ae0f177e01a04deea811e1828be35       private_equity
# 114929  /funding-round/55f33b179dd6f4516315348c1e8350c6                angel
# 114930  /funding-round/c05aab2155e390066d51c6852ff61464                grant
# 114931  /funding-round/e949f077c943db197f20e43c2eb8d0e6              venture
# 114932  /funding-round/2a13fa52848ace2760b224a350a76b40                 seed
# 114933  /funding-round/39baf35e59eb3efc5409cd4c5eaa50e1                 seed
# 114934  /funding-round/7a0fa791c96c9c447ee54662395beab9              venture
# 114935  /funding-round/cc8cd96a500332d5b4f4bcbddb306099                angel
# 114936  /funding-round/7ea37c0ff4132b084832039a9380d34e              venture
# 114937  /funding-round/0c43e717298296d2fb334fb236300f6e              venture
# 114938  /funding-round/34b560f672bebeb339a5efa3b27eae5d                grant
# 114939  /funding-round/4c82e18a8e3eab2647719d0fc27ead5f                angel
# 114940  /funding-round/73721fffc980d228f051e87422aa8732                 seed
# 114941  /funding-round/171693e1e07e0230defd8fddb6de4515              venture
# 114942  /funding-round/22ef2fafb4d20ac3aa4b86143dbf6c8e                 seed
# 114943  /funding-round/6ba41360588bc6e3f77e9b50a0ebfafa                 seed
# 114944  /funding-round/8f6d25b8ee4199e586484d817bceda05     convertible_note
# 114945  /funding-round/ff1aa06ed5da186c84f101549035d4ae                 seed
# 114946  /funding-round/59f4dce44723b794f21ded3daed6e4fe              venture
# 114947  /funding-round/35f09d0794651719b02bbfd859ba9ff5                 seed
# 114948  /funding-round/af942869878d2cd788ef5189b435ebc4                grant
#
#        funding_round_code   funded_at  raised_amount_usd  \
# 0                       B  05-01-2015          10.000000
# 1                       A  14-10-2014           7.000000
# 2                     NaN  01-03-2014           0.700000
# 3                       B  30-01-2014           3.406878
# 4                       A  19-03-2008           2.000000
# 5                     NaN  24-07-2014           7.000000
# 6                     NaN  01-07-2014           0.041250
# 7                     NaN  11-09-2009           0.043360
# 8                     NaN  21-12-2009           0.719491
# 9                     NaN  22-05-2013           3.000000
# 10                      B  09-11-2015          20.000000
# 11                    NaN  03-01-2013           1.700000
# 12                      A  19-07-2014           8.900000
# 13                    NaN  05-02-2014           0.150000
# 14                    NaN  05-02-2013           7.000000
# 15                    NaN  20-07-2011           1.000050
# 16                    NaN  18-02-2013           0.040000
# 17                    NaN  21-04-2013           7.000000
# 18                    NaN  22-01-2014           7.000000
# 19                    NaN  19-08-2010           7.000000
# 20                    NaN  02-03-2011           1.750000
# 21                    NaN  01-02-2015           6.000000
# 22                    NaN  17-03-2015           5.000000
# 23                    NaN  13-12-2014           0.100000
# 24                    NaN  11-01-2011           0.800000
# 25                    NaN  18-06-2009           0.500000
# 26                    NaN  28-12-2011           0.500000
# 27                    NaN  30-03-2010           0.250000
# 28                      A  09-10-2014           4.000000
# 29                    NaN  01-01-2013           0.400000
# ...                   ...         ...                ...
# 114919                NaN  18-09-2012           2.325000
# 114920                  B  30-06-2013          12.000000
# 114921                NaN  26-03-2014           7.500000
# 114922                NaN  11-07-2013          14.219999
# 114923                NaN  29-01-2010           0.555016
# 114924                NaN  01-04-2015           1.700000
# 114925                NaN  27-10-2015           1.600000
# 114926                NaN  25-09-2013           2.150000
# 114927                NaN  26-07-2013           7.000000
# 114928                NaN  15-02-2013           0.020967
# 114929                NaN  01-01-2008           2.007363
# 114930                NaN  11-09-2009           5.400000
# 114931                  A  09-10-2009           7.991547
# 114932                NaN  15-11-2010           0.445000
# 114933                NaN  21-10-2010           0.050000
# 114934                NaN  18-10-2012           0.140500
# 114935                NaN  15-12-2010           0.875000
# 114936                  A  16-12-2004           8.500000
# 114937                  A  29-01-2013           2.686600
# 114938                NaN  25-02-2015           0.400000
# 114939                NaN  31-10-2014           0.400000
# 114940                NaN  24-03-2014           0.320000
# 114941                  A  01-04-2012           1.587301
# 114942                NaN  01-11-2011           0.007000
# 114943                NaN  01-08-2013           0.033149
# 114944                NaN  01-03-2014           0.041313
# 114945                NaN  01-05-2013           0.032842
# 114946                  A  01-08-2014           7.000000
# 114947                NaN  01-01-2015           0.018192
# 114948                NaN  01-10-2013           0.014851
#
#                                                  name  \
# 0                                               #fame
# 1                                            :Qounter
# 2                                            :Qounter
# 3                              (THE) ONE of THEM,Inc.
# 4                                             0-6.com
# 5                                    004 Technologies
# 6                                  01Games Technology
# 7                              Ondine Biomedical Inc.
# 8                              Ondine Biomedical Inc.
# 9                                              H2O.ai
# 10                                             H2O.ai
# 11                                             H2O.ai
# 12                                             H2O.ai
# 13                                           One Inc.
# 14                                           One Inc.
# 15                                           One Inc.
# 16                                        1,2,3 Listo
# 17                                            1-4 All
# 18                                   1.618 Technology
# 19                                      1-800-DENTIST
# 20                                      1-800-DOCTORS
# 21                        1-800-PublicRelations, Inc.
# 22                                       1 Mainstream
# 23                                            1 of 99
# 24                                        10-20 Media
# 25                                        10-20 Media
# 26                                        10-20 Media
# 27                                        10-20 Media
# 28                                    10 Minutes With
# 29                                    10 Minutes With
# ...                                               ...
# 114919                                        Zynstra
# 114920                                         ZYOMYX
# 114921                                         ZYOMYX
# 114922                                         ZYOMYX
# 114923                                         ZYOMYX
# 114924                                           Zype
# 114925                                           Zype
# 114926                        Whisk (formerly Zypsee)
# 114927                        Whisk (formerly Zypsee)
# 114928                               Zyraz Technology
# 114929                               Zyraz Technology
# 114930                               Zyraz Technology
# 114931                               Zyraz Technology
# 114932                                          Zyrra
# 114933                                          Zyrra
# 114934                                          Zyrra
# 114935                                          Zyrra
# 114936                                         Zystor
# 114937                                     Zytoprotec
# 114938                                          Zzish
# 114939                                          Zzish
# 114940                                          Zzish
# 114941                  ZZNode Science and Technology
# 114942                          Zzzzapp Wireless ltd.
# 114943                          Zzzzapp Wireless ltd.
# 114944                          Zzzzapp Wireless ltd.
# 114945                          Zzzzapp Wireless ltd.
# 114946                                         ÃERON
# 114947                                         Ãasys
# 114948  Ä°novatiff Reklam ve TanÄ±tÄ±m Hizmetleri Tic
#
#                               homepage_url  \
# 0                       http://livfame.com
# 1                   http://www.qounter.com
# 2                   http://www.qounter.com
# 3                      http://oneofthem.jp
# 4                       http://www.0-6.com
# 5        http://004gmbh.de/en/004-interact
# 6                   http://www.01games.hk/
# 7                     http://ondinebio.com
# 8                     http://ondinebio.com
# 9                           http://h2o.ai/
# 10                          http://h2o.ai/
# 11                          http://h2o.ai/
# 12                          http://h2o.ai/
# 13                      http://whatis1.com
# 14                      http://whatis1.com
# 15                      http://whatis1.com
# 16                 http://www.123listo.com
# 17                                     NaN
# 18      http://www.Homeandcondogallery.com
# 19              http://www.1800dentist.com
# 20                  http://1800doctors.com
# 21      http://www.1800publicrelations.com
# 22              http://www.1mainstream.com
# 23                                     NaN
# 24               http://www.10-20media.com
# 25               http://www.10-20media.com
# 26               http://www.10-20media.com
# 27               http://www.10-20media.com
# 28                http://10minuteswith.com
# 29                http://10minuteswith.com
# ...                                    ...
# 114919              http://www.zynstra.com
# 114920               http://www.zyomyx.com
# 114921               http://www.zyomyx.com
# 114922               http://www.zyomyx.com
# 114923               http://www.zyomyx.com
# 114924                 http://www.zype.com
# 114925                 http://www.zype.com
# 114926                     http://whisk.me
# 114927                     http://whisk.me
# 114928                http://www.zyraz.com
# 114929                http://www.zyraz.com
# 114930                http://www.zyraz.com
# 114931                http://www.zyraz.com
# 114932                http://www.zyrra.com
# 114933                http://www.zyrra.com
# 114934                http://www.zyrra.com
# 114935                http://www.zyrra.com
# 114936               http://www.zystor.com
# 114937           http://www.zytoprotec.com
# 114938                http://www.zzish.com
# 114939                http://www.zzish.com
# 114940                http://www.zzish.com
# 114941               http://www.zznode.com
# 114942              http://www.zzzzapp.com
# 114943              http://www.zzzzapp.com
# 114944              http://www.zzzzapp.com
# 114945              http://www.zzzzapp.com
# 114946                http://www.aeron.hu/
# 114947                http://www.oasys.io/
# 114948                http://inovatiff.com
#
#                                             category_list     status  \
# 0                                                   Media  operating
# 1       Application Platforms|Real Time|Social Network...  operating
# 2       Application Platforms|Real Time|Social Network...  operating
# 3                                       Apps|Games|Mobile  operating
# 4                                             Curated Web  operating
# 5                                                Software  operating
# 6                                                   Games  operating
# 7                                           Biotechnology  operating
# 8                                           Biotechnology  operating
# 9                                               Analytics  operating
# 10                                              Analytics  operating
# 11                                              Analytics  operating
# 12                                              Analytics  operating
# 13                                                 Mobile  operating
# 14                                                 Mobile  operating
# 15                                                 Mobile  operating
# 16                                             E-Commerce  operating
# 17                           Entertainment|Games|Software  operating
# 18                     Networking|Real Estate|Web Hosting  operating
# 19                                    Health and Wellness  operating
# 20                                    Health and Wellness  operating
# 21              Internet Marketing|Media|Public Relations  operating
# 22                       Apps|Cable|Distribution|Software   acquired
# 23                                    Entertainment|Games  operating
# 24                                             E-Commerce  operating
# 25                                             E-Commerce  operating
# 26                                             E-Commerce  operating
# 27                                             E-Commerce  operating
# 28                                              Education  operating
# 29                                              Education  operating
# ...                                                   ...        ...
# 114919                                           Software  operating
# 114920                                      Biotechnology  operating
# 114921                                      Biotechnology  operating
# 114922                                      Biotechnology  operating
# 114923                                      Biotechnology  operating
# 114924  Cloud Computing|Mobile Advertising|Video|Video...  operating
# 114925  Cloud Computing|Mobile Advertising|Video|Video...  operating
# 114926                              Public Transportation  operating
# 114927                              Public Transportation  operating
# 114928                                      Biotechnology     closed
# 114929                                      Biotechnology     closed
# 114930                                      Biotechnology     closed
# 114931                                      Biotechnology     closed
# 114932                                         E-Commerce  operating
# 114933                                         E-Commerce  operating
# 114934                                         E-Commerce  operating
# 114935                                         E-Commerce  operating
# 114936                                      Biotechnology   acquired
# 114937                                      Biotechnology  operating
# 114938  Analytics|Android|Developer APIs|Education|Gam...  operating
# 114939  Analytics|Android|Developer APIs|Education|Gam...  operating
# 114940  Analytics|Android|Developer APIs|Education|Gam...  operating
# 114941                                Enterprise Software  operating
# 114942        Advertising|Mobile|Web Development|Wireless  operating
# 114943        Advertising|Mobile|Web Development|Wireless  operating
# 114944        Advertising|Mobile|Web Development|Wireless  operating
# 114945        Advertising|Mobile|Web Development|Wireless  operating
# 114946                                                NaN  operating
# 114947  Consumer Electronics|Internet of Things|Teleco...  operating
# 114948                 Consumer Goods|E-Commerce|Internet  operating
#
#        country_code state_code                 region                   city  \
# 0               IND         16                 Mumbai                 Mumbai
# 1               USA         DE             DE - Other          Delaware City
# 2               USA         DE             DE - Other          Delaware City
# 3               NaN        NaN                    NaN                    NaN
# 4               CHN         22                Beijing                Beijing
# 5               USA         IL  Springfield, Illinois              Champaign
# 6               HKG        NaN              Hong Kong              Hong Kong
# 7               CAN         BC              Vancouver              Vancouver
# 8               CAN         BC              Vancouver              Vancouver
# 9               USA         CA            SF Bay Area          Mountain View
# 10              USA         CA            SF Bay Area          Mountain View
# 11              USA         CA            SF Bay Area          Mountain View
# 12              USA         CA            SF Bay Area          Mountain View
# 13              USA         CA            SF Bay Area          San Francisco
# 14              USA         CA            SF Bay Area          San Francisco
# 15              USA         CA            SF Bay Area          San Francisco
# 16              CHL         12               Santiago             Las Condes
# 17              USA         NC             NC - Other      Connellys Springs
# 18              USA         FL                Orlando                Orlando
# 19              USA         CA            Los Angeles            Los Angeles
# 20              USA         NJ                 Newark                 Iselin
# 21              USA         NY          New York City               New York
# 22              USA         CA            SF Bay Area              Cupertino
# 23              USA         CA            SF Bay Area          Mountain View
# 24              USA         MD              Baltimore               Woodbine
# 25              USA         MD              Baltimore               Woodbine
# 26              USA         MD              Baltimore               Woodbine
# 27              USA         MD              Baltimore               Woodbine
# 28              GBR         H9                 London                 London
# 29              GBR         H9                 London                 London
# ...             ...        ...                    ...                    ...
# 114919          GBR         A4                   Bath                   Bath
# 114920          USA         MO             MO - Other                Fremont
# 114921          USA         MO             MO - Other                Fremont
# 114922          USA         MO             MO - Other                Fremont
# 114923          USA         MO             MO - Other                Fremont
# 114924          USA         NY          New York City               New York
# 114925          USA         NY          New York City               New York
# 114926          USA         NY          New York City               New York
# 114927          USA         NY          New York City               New York
# 114928          MYS         14            MYS - Other  Damansara New Village
# 114929          MYS         14            MYS - Other  Damansara New Village
# 114930          MYS         14            MYS - Other  Damansara New Village
# 114931          MYS         14            MYS - Other  Damansara New Village
# 114932          USA         MA                 Boston              Cambridge
# 114933          USA         MA                 Boston              Cambridge
# 114934          USA         MA                 Boston              Cambridge
# 114935          USA         MA                 Boston              Cambridge
# 114936          USA         WI              Milwaukee              Milwaukee
# 114937          AUT          3                 Vienna     Gerasdorf Bei Wien
# 114938          GBR         H9                 London                 London
# 114939          GBR         H9                 London                 London
# 114940          GBR         H9                 London                 London
# 114941          CHN         22                Beijing                Beijing
# 114942          HRV         15                  Split                  Split
# 114943          HRV         15                  Split                  Split
# 114944          HRV         15                  Split                  Split
# 114945          HRV         15                  Split                  Split
# 114946          NaN        NaN                    NaN                    NaN
# 114947          USA         CA            SF Bay Area          San Francisco
# 114948          NaN        NaN                    NaN                    NaN
#
#         founded_at
# 0              NaN
# 1       04-09-2014
# 2       04-09-2014
# 3              NaN
# 4       01-01-2007
# 5       01-01-2010
# 6              NaN
# 7       01-01-1997
# 8       01-01-1997
# 9       01-01-2011
# 10      01-01-2011
# 11      01-01-2011
# 12      01-01-2011
# 13      01-08-2011
# 14      01-08-2011
# 15      01-08-2011
# 16      01-01-2012
# 17             NaN
# 18      07-12-2013
# 19      01-01-1986
# 20      01-01-1984
# 21      24-10-2013
# 22      01-03-2012
# 23      01-12-2014
# 24      01-01-2001
# 25      01-01-2001
# 26      01-01-2001
# 27      01-01-2001
# 28      01-01-2013
# 29      01-01-2013
# ...            ...
# 114919  30-11-2011
# 114920  01-01-1998
# 114921  01-01-1998
# 114922  01-01-1998
# 114923  01-01-1998
# 114924  01-01-2013
# 114925  01-01-2013
# 114926  01-01-2011
# 114927  01-01-2011
# 114928  01-01-1994
# 114929  01-01-1994
# 114930  01-01-1994
# 114931  01-01-1994
# 114932         NaN
# 114933         NaN
# 114934         NaN
# 114935         NaN
# 114936         NaN
# 114937  01-01-2007
# 114938  28-01-2014
# 114939  28-01-2014
# 114940  28-01-2014
# 114941         NaN
# 114942  13-05-2012
# 114943  13-05-2012
# 114944  13-05-2012
# 114945  13-05-2012
# 114946  01-01-2011
# 114947  01-01-2014
# 114948         NaN
#
# [114949 rows x 15 columns]

# %% [markdown]
# # Task 11: Compute average funding amount of venture type
# ### Outcome: Item #1 in Table 2.1 of excel sheet

# %%
inv_by_funding_type['raised_amount_usd'].mean().sort_values(ascending = False)
# Out:
# funding_round_type
# post_ipo_debt            168.704572
# post_ipo_equity           81.004085
# private_equity            63.180935
# secondary_market          29.941988
# debt_financing            16.733262
# venture                   11.298306
# undisclosed               10.954958
# equity_crowdfunding        4.563745
# non_equity_assistance      4.481769
# grant                      4.393829
# convertible_note           2.582898
# angel                      2.182024
# seed                       2.143784
# product_crowdfunding       1.693094
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# # Task 12: Compute average funding amount of angel type
# ### Outcome: Item #2 in Table 2.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 13: Compute average funding amount of seed type
# ### Outcome: Item #3 in Table 2.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 14: Compute average funding amount of private equity venture type
# ### Outcome: Item #4 in Table 2.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 15: Determine most suitable investment type for Spark Funds
# ### Outcome: Item #5 in Table 2.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 16: Compute top 9 countries that have received highest total funding
# ### Outcome: top9 data frame with the top 9 countries

# %%
master_frame
inv_by_country=master_frame.groupby('country_code')
top_9=inv_by_country['raised_amount_usd'].sum().sort_values(ascending = False).head(9)
top_9
# Out:
# country_code
# USA    741295.123821
# CHN     81065.565796
# GBR     39396.048060
# IND     31774.336560
# CAN     21917.675109
# DEU     14980.763740
# RUS     11867.120120
# ISR     11582.884650
# FRA     10452.770757
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# # Task 17: Identify the top 3 English speaking countries in top9 data frame
# ### Outcome: Item #1,2,3 in Table 3.1 of excel sheet

# %%
# Insert code here

# %% [markdown]
# # Task 18: Map each company's primary sector to one of the 8 main sectors defined in the mappings.csv
# ### Outcome: Merged data frame that maps the primary sector to the main sector

# %%
primary_sector = master_frame['category_list'].str.split("|",expand=True)
master_frame['primary_sector']=primary_sector[0]
mapping_df = pd.read_csv("mapping.csv",encoding = "ISO-8859-1")

df_category_err = mapping_df[(mapping_df['category_list'].str.contains("0",na=False))&(~mapping_df['category_list'].str.contains("2.0",na=False))]
mapping_df.loc[(mapping_df['category_list'].str.contains("0",na=False))&(~mapping_df['category_list'].str.contains("2.0",na=False)),['category_list']] = df_category_err['category_list'].str.replace("0","na")

# %%
mapping_df.set_index('category_list',inplace=True)
mapping_df.index.contains('Nanotechnology')
# Out:
# False

# %%
def map_sector(sector):
    if mapping_df.index.contains(sector):
        return mapping_df.loc[sector][lambda x: x == 1].index[0]
    else:
        return "Others"

master_frame['main_sector']=list(map(map_sector,master_frame['primary_sector']))

# %%
master_frame
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 5                          /organization/004-technologies
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 14                                        /organization/1
# 15                                        /organization/1
# 16                              /organization/1-2-3-listo
# 17                                  /organization/1-4-all
# 18                         /organization/1-618-technology
# 19                            /organization/1-800-dentist
# 20                            /organization/1-800-doctors
# 21               /organization/1-800-publicrelations-inc-
# 22                             /organization/1-mainstream
# 23                                  /organization/1-of-99
# 24                              /organization/10-20-media
# 25                              /organization/10-20-media
# 26                              /organization/10-20-media
# 27                              /organization/10-20-media
# 28                          /organization/10-minutes-with
# 29                          /organization/10-minutes-with
# ...                                                   ...
# 114919                              /organization/zynstra
# 114920                           /organization/zyomyx-inc
# 114921                           /organization/zyomyx-inc
# 114922                           /organization/zyomyx-inc
# 114923                           /organization/zyomyx-inc
# 114924                                 /organization/zype
# 114925                                 /organization/zype
# 114926                               /organization/zypsee
# 114927                               /organization/zypsee
# 114928                     /organization/zyraz-technology
# 114929                     /organization/zyraz-technology
# 114930                     /organization/zyraz-technology
# 114931                     /organization/zyraz-technology
# 114932                                /organization/zyrra
# 114933                                /organization/zyrra
# 114934                                /organization/zyrra
# 114935                                /organization/zyrra
# 114936                               /organization/zystor
# 114937                           /organization/zytoprotec
# 114938                                /organization/zzish
# 114939                                /organization/zzish
# 114940                                /organization/zzish
# 114941  /organization/zznode-science-and-technology-co...
# 114942                          /organization/zzzzapp-com
# 114943                          /organization/zzzzapp-com
# 114944                          /organization/zzzzapp-com
# 114945                          /organization/zzzzapp-com
# 114946                                 /organization/eron
# 114947                               /organization/asys-2
# 114948  /organization/novatiff-reklam-ve-tantm-hizmetl...
#
#                                 funding_round_permalink   funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638              venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633              venture
# 2       /funding-round/b44fbb94153f6cdef13083530bb48030                 seed
# 3       /funding-round/650b8f704416801069bb178a1418776b              venture
# 4       /funding-round/5727accaeaa57461bd22a9bdd945382d              venture
# 5       /funding-round/1278dd4e6a37fa4b7d7e06c21b3c1830              venture
# 6       /funding-round/7d53696f2b4f607a2f2a8cbb83d01839          undisclosed
# 7       /funding-round/2b9d3ac293d5cdccbecff5c8cb0f327d                 seed
# 8       /funding-round/954b9499724b946ad8c396a57a5f3b72              venture
# 9       /funding-round/383a9bd2c04f7038bb543ccef5ba3eae                 seed
# 10      /funding-round/3bb2ee4a2d89251a10aaa735b1180e44              venture
# 11      /funding-round/ae2a174c06517c2394aed45006322a7e              venture
# 12      /funding-round/e1cfcbe1bdf4c70277c5f29a3482f24e              venture
# 13      /funding-round/03b975068632eba5bfdb937ec8c07a68                 seed
# 14      /funding-round/5de6d8828aef7d925d97918d15727670          undisclosed
# 15      /funding-round/e82464f22241715dd1a6c77241055ed1                 seed
# 16      /funding-round/6de4609e894495105bc791ed64361288                 seed
# 17      /funding-round/e97a192e13ea0ee3c4f71136b4f3ec16  equity_crowdfunding
# 18      /funding-round/83b8f4c7d37ecef5e001a5e953bf461a  equity_crowdfunding
# 19      /funding-round/5274aacc211163fc7c86539ce94bbacc          undisclosed
# 20      /funding-round/9eb8c7790a0c200d79e75785d1c4aa12     convertible_note
# 21      /funding-round/11c228f58831bc7ed337ef69ecc560c2       private_equity
# 22      /funding-round/b952cbaf401f310927430c97b68162ea              venture
# 23      /funding-round/b5c811f561cfb5701cd5b1762120bbc3     convertible_note
# 24      /funding-round/436874dc54b54460f99f44c06e50990a       debt_financing
# 25      /funding-round/8025ee9c11a586eac4a234ddec7beb30       debt_financing
# 26      /funding-round/a884bf8326b9fd59789c0f74a28dbc3b       debt_financing
# 27      /funding-round/d205f5416ce55e126beda3ed2bf2c2cd       debt_financing
# 28      /funding-round/0faccbbcc5818dc5326469f13f5a8ac8              venture
# 29      /funding-round/f245a74b4c54610ae843e17bdf4d1113                 seed
# ...                                                 ...                  ...
# 114919  /funding-round/dee233b3434185c14b3352034f72d798                angel
# 114920  /funding-round/4191cb5258d3863b0212d1083881da64              venture
# 114921  /funding-round/85443f5438bfd50104b9591eabc95c94                grant
# 114922  /funding-round/b4fce7f8a13267353d57db09099800e8              venture
# 114923  /funding-round/ea5b21da6cf999ff4d5667431fe318d7              venture
# 114924  /funding-round/24e8134882bf6c4dcc385abba0acd5d9                 seed
# 114925  /funding-round/c9f5097b3617c7539aa47c8b448163be                 seed
# 114926  /funding-round/472c6f7940522552fcca465b8cd3deef                 seed
# 114927  /funding-round/c67e22c5448435adaf5a2d101e449dde                 seed
# 114928  /funding-round/3c3ae0f177e01a04deea811e1828be35       private_equity
# 114929  /funding-round/55f33b179dd6f4516315348c1e8350c6                angel
# 114930  /funding-round/c05aab2155e390066d51c6852ff61464                grant
# 114931  /funding-round/e949f077c943db197f20e43c2eb8d0e6              venture
# 114932  /funding-round/2a13fa52848ace2760b224a350a76b40                 seed
# 114933  /funding-round/39baf35e59eb3efc5409cd4c5eaa50e1                 seed
# 114934  /funding-round/7a0fa791c96c9c447ee54662395beab9              venture
# 114935  /funding-round/cc8cd96a500332d5b4f4bcbddb306099                angel
# 114936  /funding-round/7ea37c0ff4132b084832039a9380d34e              venture
# 114937  /funding-round/0c43e717298296d2fb334fb236300f6e              venture
# 114938  /funding-round/34b560f672bebeb339a5efa3b27eae5d                grant
# 114939  /funding-round/4c82e18a8e3eab2647719d0fc27ead5f                angel
# 114940  /funding-round/73721fffc980d228f051e87422aa8732                 seed
# 114941  /funding-round/171693e1e07e0230defd8fddb6de4515              venture
# 114942  /funding-round/22ef2fafb4d20ac3aa4b86143dbf6c8e                 seed
# 114943  /funding-round/6ba41360588bc6e3f77e9b50a0ebfafa                 seed
# 114944  /funding-round/8f6d25b8ee4199e586484d817bceda05     convertible_note
# 114945  /funding-round/ff1aa06ed5da186c84f101549035d4ae                 seed
# 114946  /funding-round/59f4dce44723b794f21ded3daed6e4fe              venture
# 114947  /funding-round/35f09d0794651719b02bbfd859ba9ff5                 seed
# 114948  /funding-round/af942869878d2cd788ef5189b435ebc4                grant
#
#        funding_round_code   funded_at  raised_amount_usd  \
# 0                       B  05-01-2015          10.000000
# 1                       A  14-10-2014           7.000000
# 2                     NaN  01-03-2014           0.700000
# 3                       B  30-01-2014           3.406878
# 4                       A  19-03-2008           2.000000
# 5                     NaN  24-07-2014           7.000000
# 6                     NaN  01-07-2014           0.041250
# 7                     NaN  11-09-2009           0.043360
# 8                     NaN  21-12-2009           0.719491
# 9                     NaN  22-05-2013           3.000000
# 10                      B  09-11-2015          20.000000
# 11                    NaN  03-01-2013           1.700000
# 12                      A  19-07-2014           8.900000
# 13                    NaN  05-02-2014           0.150000
# 14                    NaN  05-02-2013           7.000000
# 15                    NaN  20-07-2011           1.000050
# 16                    NaN  18-02-2013           0.040000
# 17                    NaN  21-04-2013           7.000000
# 18                    NaN  22-01-2014           7.000000
# 19                    NaN  19-08-2010           7.000000
# 20                    NaN  02-03-2011           1.750000
# 21                    NaN  01-02-2015           6.000000
# 22                    NaN  17-03-2015           5.000000
# 23                    NaN  13-12-2014           0.100000
# 24                    NaN  11-01-2011           0.800000
# 25                    NaN  18-06-2009           0.500000
# 26                    NaN  28-12-2011           0.500000
# 27                    NaN  30-03-2010           0.250000
# 28                      A  09-10-2014           4.000000
# 29                    NaN  01-01-2013           0.400000
# ...                   ...         ...                ...
# 114919                NaN  18-09-2012           2.325000
# 114920                  B  30-06-2013          12.000000
# 114921                NaN  26-03-2014           7.500000
# 114922                NaN  11-07-2013          14.219999
# 114923                NaN  29-01-2010           0.555016
# 114924                NaN  01-04-2015           1.700000
# 114925                NaN  27-10-2015           1.600000
# 114926                NaN  25-09-2013           2.150000
# 114927                NaN  26-07-2013           7.000000
# 114928                NaN  15-02-2013           0.020967
# 114929                NaN  01-01-2008           2.007363
# 114930                NaN  11-09-2009           5.400000
# 114931                  A  09-10-2009           7.991547
# 114932                NaN  15-11-2010           0.445000
# 114933                NaN  21-10-2010           0.050000
# 114934                NaN  18-10-2012           0.140500
# 114935                NaN  15-12-2010           0.875000
# 114936                  A  16-12-2004           8.500000
# 114937                  A  29-01-2013           2.686600
# 114938                NaN  25-02-2015           0.400000
# 114939                NaN  31-10-2014           0.400000
# 114940                NaN  24-03-2014           0.320000
# 114941                  A  01-04-2012           1.587301
# 114942                NaN  01-11-2011           0.007000
# 114943                NaN  01-08-2013           0.033149
# 114944                NaN  01-03-2014           0.041313
# 114945                NaN  01-05-2013           0.032842
# 114946                  A  01-08-2014           7.000000
# 114947                NaN  01-01-2015           0.018192
# 114948                NaN  01-10-2013           0.014851
#
#                                                  name  \
# 0                                               #fame
# 1                                            :Qounter
# 2                                            :Qounter
# 3                              (THE) ONE of THEM,Inc.
# 4                                             0-6.com
# 5                                    004 Technologies
# 6                                  01Games Technology
# 7                              Ondine Biomedical Inc.
# 8                              Ondine Biomedical Inc.
# 9                                              H2O.ai
# 10                                             H2O.ai
# 11                                             H2O.ai
# 12                                             H2O.ai
# 13                                           One Inc.
# 14                                           One Inc.
# 15                                           One Inc.
# 16                                        1,2,3 Listo
# 17                                            1-4 All
# 18                                   1.618 Technology
# 19                                      1-800-DENTIST
# 20                                      1-800-DOCTORS
# 21                        1-800-PublicRelations, Inc.
# 22                                       1 Mainstream
# 23                                            1 of 99
# 24                                        10-20 Media
# 25                                        10-20 Media
# 26                                        10-20 Media
# 27                                        10-20 Media
# 28                                    10 Minutes With
# 29                                    10 Minutes With
# ...                                               ...
# 114919                                        Zynstra
# 114920                                         ZYOMYX
# 114921                                         ZYOMYX
# 114922                                         ZYOMYX
# 114923                                         ZYOMYX
# 114924                                           Zype
# 114925                                           Zype
# 114926                        Whisk (formerly Zypsee)
# 114927                        Whisk (formerly Zypsee)
# 114928                               Zyraz Technology
# 114929                               Zyraz Technology
# 114930                               Zyraz Technology
# 114931                               Zyraz Technology
# 114932                                          Zyrra
# 114933                                          Zyrra
# 114934                                          Zyrra
# 114935                                          Zyrra
# 114936                                         Zystor
# 114937                                     Zytoprotec
# 114938                                          Zzish
# 114939                                          Zzish
# 114940                                          Zzish
# 114941                  ZZNode Science and Technology
# 114942                          Zzzzapp Wireless ltd.
# 114943                          Zzzzapp Wireless ltd.
# 114944                          Zzzzapp Wireless ltd.
# 114945                          Zzzzapp Wireless ltd.
# 114946                                         ÃERON
# 114947                                         Ãasys
# 114948  Ä°novatiff Reklam ve TanÄ±tÄ±m Hizmetleri Tic
#
#                               homepage_url  \
# 0                       http://livfame.com
# 1                   http://www.qounter.com
# 2                   http://www.qounter.com
# 3                      http://oneofthem.jp
# 4                       http://www.0-6.com
# 5        http://004gmbh.de/en/004-interact
# 6                   http://www.01games.hk/
# 7                     http://ondinebio.com
# 8                     http://ondinebio.com
# 9                           http://h2o.ai/
# 10                          http://h2o.ai/
# 11                          http://h2o.ai/
# 12                          http://h2o.ai/
# 13                      http://whatis1.com
# 14                      http://whatis1.com
# 15                      http://whatis1.com
# 16                 http://www.123listo.com
# 17                                     NaN
# 18      http://www.Homeandcondogallery.com
# 19              http://www.1800dentist.com
# 20                  http://1800doctors.com
# 21      http://www.1800publicrelations.com
# 22              http://www.1mainstream.com
# 23                                     NaN
# 24               http://www.10-20media.com
# 25               http://www.10-20media.com
# 26               http://www.10-20media.com
# 27               http://www.10-20media.com
# 28                http://10minuteswith.com
# 29                http://10minuteswith.com
# ...                                    ...
# 114919              http://www.zynstra.com
# 114920               http://www.zyomyx.com
# 114921               http://www.zyomyx.com
# 114922               http://www.zyomyx.com
# 114923               http://www.zyomyx.com
# 114924                 http://www.zype.com
# 114925                 http://www.zype.com
# 114926                     http://whisk.me
# 114927                     http://whisk.me
# 114928                http://www.zyraz.com
# 114929                http://www.zyraz.com
# 114930                http://www.zyraz.com
# 114931                http://www.zyraz.com
# 114932                http://www.zyrra.com
# 114933                http://www.zyrra.com
# 114934                http://www.zyrra.com
# 114935                http://www.zyrra.com
# 114936               http://www.zystor.com
# 114937           http://www.zytoprotec.com
# 114938                http://www.zzish.com
# 114939                http://www.zzish.com
# 114940                http://www.zzish.com
# 114941               http://www.zznode.com
# 114942              http://www.zzzzapp.com
# 114943              http://www.zzzzapp.com
# 114944              http://www.zzzzapp.com
# 114945              http://www.zzzzapp.com
# 114946                http://www.aeron.hu/
# 114947                http://www.oasys.io/
# 114948                http://inovatiff.com
#
#                                             category_list     status  \
# 0                                                   Media  operating
# 1       Application Platforms|Real Time|Social Network...  operating
# 2       Application Platforms|Real Time|Social Network...  operating
# 3                                       Apps|Games|Mobile  operating
# 4                                             Curated Web  operating
# 5                                                Software  operating
# 6                                                   Games  operating
# 7                                           Biotechnology  operating
# 8                                           Biotechnology  operating
# 9                                               Analytics  operating
# 10                                              Analytics  operating
# 11                                              Analytics  operating
# 12                                              Analytics  operating
# 13                                                 Mobile  operating
# 14                                                 Mobile  operating
# 15                                                 Mobile  operating
# 16                                             E-Commerce  operating
# 17                           Entertainment|Games|Software  operating
# 18                     Networking|Real Estate|Web Hosting  operating
# 19                                    Health and Wellness  operating
# 20                                    Health and Wellness  operating
# 21              Internet Marketing|Media|Public Relations  operating
# 22                       Apps|Cable|Distribution|Software   acquired
# 23                                    Entertainment|Games  operating
# 24                                             E-Commerce  operating
# 25                                             E-Commerce  operating
# 26                                             E-Commerce  operating
# 27                                             E-Commerce  operating
# 28                                              Education  operating
# 29                                              Education  operating
# ...                                                   ...        ...
# 114919                                           Software  operating
# 114920                                      Biotechnology  operating
# 114921                                      Biotechnology  operating
# 114922                                      Biotechnology  operating
# 114923                                      Biotechnology  operating
# 114924  Cloud Computing|Mobile Advertising|Video|Video...  operating
# 114925  Cloud Computing|Mobile Advertising|Video|Video...  operating
# 114926                              Public Transportation  operating
# 114927                              Public Transportation  operating
# 114928                                      Biotechnology     closed
# 114929                                      Biotechnology     closed
# 114930                                      Biotechnology     closed
# 114931                                      Biotechnology     closed
# 114932                                         E-Commerce  operating
# 114933                                         E-Commerce  operating
# 114934                                         E-Commerce  operating
# 114935                                         E-Commerce  operating
# 114936                                      Biotechnology   acquired
# 114937                                      Biotechnology  operating
# 114938  Analytics|Android|Developer APIs|Education|Gam...  operating
# 114939  Analytics|Android|Developer APIs|Education|Gam...  operating
# 114940  Analytics|Android|Developer APIs|Education|Gam...  operating
# 114941                                Enterprise Software  operating
# 114942        Advertising|Mobile|Web Development|Wireless  operating
# 114943        Advertising|Mobile|Web Development|Wireless  operating
# 114944        Advertising|Mobile|Web Development|Wireless  operating
# 114945        Advertising|Mobile|Web Development|Wireless  operating
# 114946                                                NaN  operating
# 114947  Consumer Electronics|Internet of Things|Teleco...  operating
# 114948                 Consumer Goods|E-Commerce|Internet  operating
#
#        country_code state_code                 region                   city  \
# 0               IND         16                 Mumbai                 Mumbai
# 1               USA         DE             DE - Other          Delaware City
# 2               USA         DE             DE - Other          Delaware City
# 3               NaN        NaN                    NaN                    NaN
# 4               CHN         22                Beijing                Beijing
# 5               USA         IL  Springfield, Illinois              Champaign
# 6               HKG        NaN              Hong Kong              Hong Kong
# 7               CAN         BC              Vancouver              Vancouver
# 8               CAN         BC              Vancouver              Vancouver
# 9               USA         CA            SF Bay Area          Mountain View
# 10              USA         CA            SF Bay Area          Mountain View
# 11              USA         CA            SF Bay Area          Mountain View
# 12              USA         CA            SF Bay Area          Mountain View
# 13              USA         CA            SF Bay Area          San Francisco
# 14              USA         CA            SF Bay Area          San Francisco
# 15              USA         CA            SF Bay Area          San Francisco
# 16              CHL         12               Santiago             Las Condes
# 17              USA         NC             NC - Other      Connellys Springs
# 18              USA         FL                Orlando                Orlando
# 19              USA         CA            Los Angeles            Los Angeles
# 20              USA         NJ                 Newark                 Iselin
# 21              USA         NY          New York City               New York
# 22              USA         CA            SF Bay Area              Cupertino
# 23              USA         CA            SF Bay Area          Mountain View
# 24              USA         MD              Baltimore               Woodbine
# 25              USA         MD              Baltimore               Woodbine
# 26              USA         MD              Baltimore               Woodbine
# 27              USA         MD              Baltimore               Woodbine
# 28              GBR         H9                 London                 London
# 29              GBR         H9                 London                 London
# ...             ...        ...                    ...                    ...
# 114919          GBR         A4                   Bath                   Bath
# 114920          USA         MO             MO - Other                Fremont
# 114921          USA         MO             MO - Other                Fremont
# 114922          USA         MO             MO - Other                Fremont
# 114923          USA         MO             MO - Other                Fremont
# 114924          USA         NY          New York City               New York
# 114925          USA         NY          New York City               New York
# 114926          USA         NY          New York City               New York
# 114927          USA         NY          New York City               New York
# 114928          MYS         14            MYS - Other  Damansara New Village
# 114929          MYS         14            MYS - Other  Damansara New Village
# 114930          MYS         14            MYS - Other  Damansara New Village
# 114931          MYS         14            MYS - Other  Damansara New Village
# 114932          USA         MA                 Boston              Cambridge
# 114933          USA         MA                 Boston              Cambridge
# 114934          USA         MA                 Boston              Cambridge
# 114935          USA         MA                 Boston              Cambridge
# 114936          USA         WI              Milwaukee              Milwaukee
# 114937          AUT          3                 Vienna     Gerasdorf Bei Wien
# 114938          GBR         H9                 London                 London
# 114939          GBR         H9                 London                 London
# 114940          GBR         H9                 London                 London
# 114941          CHN         22                Beijing                Beijing
# 114942          HRV         15                  Split                  Split
# 114943          HRV         15                  Split                  Split
# 114944          HRV         15                  Split                  Split
# 114945          HRV         15                  Split                  Split
# 114946          NaN        NaN                    NaN                    NaN
# 114947          USA         CA            SF Bay Area          San Francisco
# 114948          NaN        NaN                    NaN                    NaN
#
#         founded_at         primary_sector  \
# 0              NaN                  Media
# 1       04-09-2014  Application Platforms
# 2       04-09-2014  Application Platforms
# 3              NaN                   Apps
# 4       01-01-2007            Curated Web
# 5       01-01-2010               Software
# 6              NaN                  Games
# 7       01-01-1997          Biotechnology
# 8       01-01-1997          Biotechnology
# 9       01-01-2011              Analytics
# 10      01-01-2011              Analytics
# 11      01-01-2011              Analytics
# 12      01-01-2011              Analytics
# 13      01-08-2011                 Mobile
# 14      01-08-2011                 Mobile
# 15      01-08-2011                 Mobile
# 16      01-01-2012             E-Commerce
# 17             NaN          Entertainment
# 18      07-12-2013             Networking
# 19      01-01-1986    Health and Wellness
# 20      01-01-1984    Health and Wellness
# 21      24-10-2013     Internet Marketing
# 22      01-03-2012                   Apps
# 23      01-12-2014          Entertainment
# 24      01-01-2001             E-Commerce
# 25      01-01-2001             E-Commerce
# 26      01-01-2001             E-Commerce
# 27      01-01-2001             E-Commerce
# 28      01-01-2013              Education
# 29      01-01-2013              Education
# ...            ...                    ...
# 114919  30-11-2011               Software
# 114920  01-01-1998          Biotechnology
# 114921  01-01-1998          Biotechnology
# 114922  01-01-1998          Biotechnology
# 114923  01-01-1998          Biotechnology
# 114924  01-01-2013        Cloud Computing
# 114925  01-01-2013        Cloud Computing
# 114926  01-01-2011  Public Transportation
# 114927  01-01-2011  Public Transportation
# 114928  01-01-1994          Biotechnology
# 114929  01-01-1994          Biotechnology
# 114930  01-01-1994          Biotechnology
# 114931  01-01-1994          Biotechnology
# 114932         NaN             E-Commerce
# 114933         NaN             E-Commerce
# 114934         NaN             E-Commerce
# 114935         NaN             E-Commerce
# 114936         NaN          Biotechnology
# 114937  01-01-2007          Biotechnology
# 114938  28-01-2014              Analytics
# 114939  28-01-2014              Analytics
# 114940  28-01-2014              Analytics
# 114941         NaN    Enterprise Software
# 114942  13-05-2012            Advertising
# 114943  13-05-2012            Advertising
# 114944  13-05-2012            Advertising
# 114945  13-05-2012            Advertising
# 114946  01-01-2011                    NaN
# 114947  01-01-2014   Consumer Electronics
# 114948         NaN         Consumer Goods
#
#                                     main_sector
# 0                                 Entertainment
# 1                    News, Search and Messaging
# 2                    News, Search and Messaging
# 3                    News, Search and Messaging
# 4                    News, Search and Messaging
# 5                                        Others
# 6                                 Entertainment
# 7                    Cleantech / Semiconductors
# 8                    Cleantech / Semiconductors
# 9       Social, Finance, Analytics, Advertising
# 10      Social, Finance, Analytics, Advertising
# 11      Social, Finance, Analytics, Advertising
# 12      Social, Finance, Analytics, Advertising
# 13                   News, Search and Messaging
# 14                   News, Search and Messaging
# 15                   News, Search and Messaging
# 16                                       Others
# 17                                Entertainment
# 18                                       Others
# 19                                       Health
# 20                                       Health
# 21      Social, Finance, Analytics, Advertising
# 22                   News, Search and Messaging
# 23                                Entertainment
# 24                                       Others
# 25                                       Others
# 26                                       Others
# 27                                       Others
# 28                                       Others
# 29                                       Others
# ...                                         ...
# 114919                                   Others
# 114920               Cleantech / Semiconductors
# 114921               Cleantech / Semiconductors
# 114922               Cleantech / Semiconductors
# 114923               Cleantech / Semiconductors
# 114924               News, Search and Messaging
# 114925               News, Search and Messaging
# 114926                                   Health
# 114927                                   Health
# 114928               Cleantech / Semiconductors
# 114929               Cleantech / Semiconductors
# 114930               Cleantech / Semiconductors
# 114931               Cleantech / Semiconductors
# 114932                                   Others
# 114933                                   Others
# 114934                                   Others
# 114935                                   Others
# 114936               Cleantech / Semiconductors
# 114937               Cleantech / Semiconductors
# 114938  Social, Finance, Analytics, Advertising
# 114939  Social, Finance, Analytics, Advertising
# 114940  Social, Finance, Analytics, Advertising
# 114941                                   Others
# 114942  Social, Finance, Analytics, Advertising
# 114943  Social, Finance, Analytics, Advertising
# 114944  Social, Finance, Analytics, Advertising
# 114945  Social, Finance, Analytics, Advertising
# 114946                                   Blanks
# 114947                            Manufacturing
# 114948                            Manufacturing
#
# [114949 rows x 17 columns]

# %% [markdown]
# # Task 19: Compute the most heavily invested main sector in each of the 3 countries (identified in Task 17) for the selected funding type (identifed in Task 15) and investments in the range of 5 - 15 million USD
# ### Outcome: 3 separate data frames for - one for each of the 3 countries containing observations for the selected funding type falling within the 5 - 15 million USD range.

# %%
inv_by_main_sector_usa=master_frame.loc[(master_frame['country_code'] =='USA') & (master_frame['funding_round_type']=='venture') & (master_frame['raised_amount_usd'] >=5) & (master_frame['raised_amount_usd'] <=15),:].groupby('main_sector')

inv_by_main_sector_usa.raised_amount_usd.sum().sort_values(ascending = False)
# Out:
# main_sector
# Others                                     29996.296561
# Social, Finance, Analytics, Advertising    27839.376964
# Cleantech / Semiconductors                 23054.628192
# News, Search and Messaging                 15793.567428
# Health                                      9219.859357
# Manufacturing                               8588.553378
# Entertainment                               6030.197982
# Automotive & Sports                         1881.104361
# Blanks                                      1758.763292
# Name: raised_amount_usd, dtype: float64

# %%
df_main_sector_gbr=master_frame.loc[(master_frame['country_code'] =='GBR') & (master_frame['funding_round_type']=='venture') & (master_frame['raised_amount_usd'] >=5) & (master_frame['raised_amount_usd'] <=15),:]
inv_by_main_sector_gbr = df_main_sector_gbr.groupby('main_sector')
pd.value_counts(df_main_sector_gbr['main_sector'].values, sort=False)
inv_by_main_sector_gbr.main_sector.count()
#inv_by_main_sector_gbr.raised_amount_usd.sum()
# Out:
# company_permalink          80
# funding_round_permalink    80
# funding_round_type         80
# funding_round_code         48
# funded_at                  80
# raised_amount_usd          80
# name                       80
# homepage_url               77
# category_list              80
# status                     80
# country_code               80
# state_code                 78
# region                     77
# city                       77
# founded_at                 66
# primary_sector             80
# main_sector                80
# dtype: int64

# %%
inv_by_main_sector_ind=master_frame.loc[(master_frame['country_code'] =='IND') & (master_frame['funding_round_type']=='venture') & (master_frame['raised_amount_usd'] >=5) & (master_frame['raised_amount_usd'] <=15),:].groupby('main_sector')

inv_by_main_sector_ind.raised_amount_usd.sum().sort_values(ascending = False)
# Out:
# main_sector
# Others                                     1349.409507
# Social, Finance, Analytics, Advertising     872.549550
# News, Search and Messaging                  601.834545
# Entertainment                               378.830000
# Health                                      265.740000
# Manufacturing                               263.900000
# Cleantech / Semiconductors                  228.380000
# Automotive & Sports                         143.900000
# Blanks                                       48.000000
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# # Task 20: Determine the main sectors and countries Sparks Funds should invest by filling up Table 5.1 of excel sheet
# ### Outcome: Filled up Table 5.1 in excel sheet

# %%
def map_sector(df,sector):
    return df.loc[sector][lambda x: x == 1].index[0]

mapping_df = pd.read_csv("mapping.csv",encoding = "ISO-8859-1")
mapping_df.set_index('category_list',inplace=True)

main_sector = map_sector(mapping_df,'3D Printing')
main_sector

#column_value = np.array(df_mapping.columns.tolist())
#column_value = column_value.reshape(1,10)
#df_mapping_list = pd.melt(df_mapping, id_vars=['category_list'], value_vars=print(column_value))
#df_mapping_list
#df_mapping_list = df_mapping_list[df_mapping_list["value"]==1]
#df_mapping_list
# Out:
# 'Manufacturing'

# %% [markdown]
# # Task 21: Create a plot showing the fraction of total investments (globally) in venture, seed, and private equity, and the average amount of investment in each funding type
# ### Outcome: Tableau plot

# %%
# Insert code to export data for use in Tableau??

# %% [markdown]
# # Task 22: Create a plot showing the top 9 countries against the total amount of investments for the selected funding type
# ### Outcome: Tableau plot

# %%
# Insert code to export data for use in Tableau??

# %% [markdown]
# # Task 23: A plot showing the number of investments in the top 3 sectors of the top 3 countries on one chart for the selected investment type
# ### Outcome: Tableau Plot

# %%
# Insert code to export data for use in Tableau??
