# %%
# Investment case study python file
# Supress Warnings
# Test Commit by Krishnan - 20 Jan 2019

import warnings
warnings.filterwarnings('ignore')

# Import the numpy and pandas packages

import numpy as np
import pandas as pd
